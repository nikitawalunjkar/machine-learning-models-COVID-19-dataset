# %% [markdown]
# ## **Installing libraries**

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in c:\users\nikita\anaconda3\envs\rdkit\lib\site-packages (0.10.2)
# Requirement already satisfied: easydict in c:\users\nikita\anaconda3\envs\rdkit\lib\site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: urllib3 in c:\users\nikita\anaconda3\envs\rdkit\lib\site-packages (from chembl_webresource_client) (1.25.10)
# Requirement already satisfied: requests>=2.18.4 in c:\users\nikita\anaconda3\envs\rdkit\lib\site-packages (from chembl_webresource_client) (2.24.0)
# Requirement already satisfied: requests-cache>=0.4.7 in c:\users\nikita\anaconda3\envs\rdkit\lib\site-packages (from chembl_webresource_client) (0.5.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nikita\anaconda3\envs\rdkit\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nikita\anaconda3\envs\rdkit\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nikita\anaconda3\envs\rdkit\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                   SARS coronavirus   14.0
# 2                                 Feline coronavirus   14.0
# 3                             Human coronavirus 229E   13.0
# 4                SARS coronavirus 3C-like proteinase   10.0
# 5  Middle East respiratory syndrome-related coron...    9.0
# 6                          Replicase polyprotein 1ab    5.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612575
# 2               False     CHEMBL612744
# 3               False     CHEMBL613837
# 4               False       CHEMBL3927
# 5               False    CHEMBL4296578
# 6               False       CHEMBL5118
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM   227859
# 2                                                 []        ORGANISM    12663
# 3                                                 []        ORGANISM    11137
# 4  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   227859
# 5                                                 []        ORGANISM  1335626
# 6  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   227859

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None      1480935                  []    CHEMBL829584
# 1             None      1480936                  []    CHEMBL829584
# 2             None      1481061                  []    CHEMBL830868
#
#                                    assay_description assay_type bao_endpoint  \
# 0  In vitro inhibitory concentration against SARS...          B  BAO_0000190
# 1  In vitro inhibitory concentration against SARS...          B  BAO_0000190
# 2  In vitro inhibitory concentration against SARS...          B  BAO_0000190
#
#     bao_format              bao_label  \
# 0  BAO_0000357  single protein format
# 1  BAO_0000357  single protein format
# 2  BAO_0000357  single protein format
#
#                           canonical_smiles  ...   target_organism  \
# 0   Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21  ...  SARS coronavirus
# 1   O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21  ...  SARS coronavirus
# 2  O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21  ...  SARS coronavirus
#
#                       target_pref_name target_tax_id text_value  toid  type  \
# 0  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 1  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 2  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
#
#   units    uo_units upper_value value
# 0    uM  UO_0000065        None   7.2
# 1    uM  UO_0000065        None   9.4
# 2    uM  UO_0000065        None  13.5
#
# [3 rows x 43 columns]

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 128             None     12041507                  []   CHEMBL2150313
# 129             None     12041508                  []   CHEMBL2150313
# 130             None     12041509                  []   CHEMBL2150313
# 131             None     12041510                  []   CHEMBL2150313
# 132             None     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# 0    In vitro inhibitory concentration against SARS...          B
# 1    In vitro inhibitory concentration against SARS...          B
# 2    In vitro inhibitory concentration against SARS...          B
# 3    In vitro inhibitory concentration against SARS...          B
# 4    In vitro inhibitory concentration against SARS...          B
# ..                                                 ...        ...
# 128  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 129  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 130  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 131  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 132  Inhibition of SARS-CoV PLpro expressed in Esch...          B
#
#     bao_endpoint   bao_format              bao_label  \
# 0    BAO_0000190  BAO_0000357  single protein format
# 1    BAO_0000190  BAO_0000357  single protein format
# 2    BAO_0000190  BAO_0000357  single protein format
# 3    BAO_0000190  BAO_0000357  single protein format
# 4    BAO_0000190  BAO_0000357  single protein format
# ..           ...          ...                    ...
# 128  BAO_0000190  BAO_0000019           assay format
# 129  BAO_0000190  BAO_0000019           assay format
# 130  BAO_0000190  BAO_0000019           assay format
# 131  BAO_0000190  BAO_0000019           assay format
# 132  BAO_0000190  BAO_0000019           assay format
#
#                                       canonical_smiles  ...   target_organism  \
# 0               Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21  ...  SARS coronavirus
# 1               O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21  ...  SARS coronavirus
# 2              O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21  ...  SARS coronavirus
# 3                  O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21  ...  SARS coronavirus
# 4      O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]  ...  SARS coronavirus
# ..                                                 ...  ...               ...
# 128  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...  ...  SARS coronavirus
# 129        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C  ...  SARS coronavirus
# 130             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12  ...  SARS coronavirus
# 131      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1  ...  SARS coronavirus
# 132             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C  ...  SARS coronavirus
#
#                         target_pref_name target_tax_id text_value  toid  type  \
# 0    SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 1    SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 2    SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 3    SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 4    SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# ..                                   ...           ...        ...   ...   ...
# 128  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 129  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 130  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 131  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
# 132  SARS coronavirus 3C-like proteinase        227859       None  None  IC50
#
#     units    uo_units upper_value  value
# 0      uM  UO_0000065        None    7.2
# 1      uM  UO_0000065        None    9.4
# 2      uM  UO_0000065        None   13.5
# 3      uM  UO_0000065        None  13.11
# 4      uM  UO_0000065        None    2.0
# ..    ...         ...         ...    ...
# 128    uM  UO_0000065        None   10.6
# 129    uM  UO_0000065        None   10.1
# 130    uM  UO_0000065        None   11.5
# 131    uM  UO_0000065        None   10.7
# 132    uM  UO_0000065        None   78.9
#
# [133 rows x 43 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value
# 0           7200.0
# 1           9400.0
# 2          13500.0
# 3          13110.0
# 4           2000.0
# ..             ...
# 128        10600.0
# 129        10100.0
# 130        11500.0
# 131        10700.0
# 132        78900.0
#
# [133 rows x 3 columns]

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value bioactivity_class
# 0           7200.0      intermediate
# 1           9400.0      intermediate
# 2          13500.0          inactive
# 3          13110.0          inactive
# 4           2000.0      intermediate
# ..             ...               ...
# 128        10600.0          inactive
# 129        10100.0          inactive
# 130        11500.0          inactive
# 131        10700.0          inactive
# 132        78900.0          inactive
#
# [133 rows x 4 columns]

# %%
df4.to_csv('bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ---
